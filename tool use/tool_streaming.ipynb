# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic


load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions


def add_user_message(messages, message):
    if isinstance(message, list):
        user_message = {
            "role": "user",
            "content": message,
        }
    else:
        user_message = {
            "role": "user",
            "content": [{"type": "text", "text": message}],
        }
    messages.append(user_message)


def add_assistant_message(messages, message):
    if isinstance(message, list):
        assistant_message = {
            "role": "assistant",
            "content": message,
        }
    elif hasattr(message, "content"):
        content_list = []
        for block in message.content:
            if block.type == "text":
                content_list.append({"type": "text", "text": block.text})
            elif block.type == "tool_use":
                content_list.append(
                    {
                        "type": "tool_use",
                        "id": block.id,
                        "name": block.name,
                        "input": block.input,
                    }
                )
        assistant_message = {
            "role": "assistant",
            "content": content_list,
        }
    else:
        # String messages need to be wrapped in a list with text block
        assistant_message = {
            "role": "assistant",
            "content": [{"type": "text", "text": message}],
        }
    messages.append(assistant_message)


def chat_stream(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    tool_choice=None,
    betas=[],
):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tool_choice:
        params["tool_choice"] = tool_choice

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    if betas:
        params["betas"] = betas

    return client.beta.messages.stream(**params)


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Tool definition
from anthropic.types import ToolParam

save_article_schema = ToolParam(
    {
        "name": "save_article",
        "description": "Saves a scholarly journal article",
        "input_schema": {
            "type": "object",
            "properties": {
                "abstract": {
                    "type": "string",
                    "description": "Abstract of the article. One short sentence max",
                },
                "meta": {
                    "type": "object",
                    "properties": {
                        "word_count": {
                            "type": "integer",
                            "description": "Word count",
                        },
                        "review": {
                            "type": "string",
                            "description": "Eight sentence review of the paper",
                        },
                    },
                    "required": ["word_count", "review"],
                },
            },
            "required": ["abstract", "meta"],
        },
    }
)
save_short_article_schema = ToolParam(
    {
        "name": "save_article",
        "description": "Saves a scholarly journal article",
        "input_schema": {
            "type": "object",
            "properties": {
                "abstract": {
                    "type": "string",
                    "description": "Abstract of the article. One short sentence max",
                },
                "meta": {
                    "type": "object",
                    "properties": {
                        "word_count": {
                            "type": "integer",
                            "description": "Word count",
                        },
                        "review": {
                            "type": "string",
                            "description": "Review of paper. One short sentence max",
                        },
                    },
                    "required": ["word_count", "review"],
                },
            },
            "required": ["abstract", "meta"],
        },
    }
)


def save_article(**kwargs):
    return "Article saved!"

# %%
# Tool Running
import json


def run_tool(tool_name, tool_input):
    if tool_name == "save_article":
        return save_article(**tool_input)


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Run conversation
def run_conversation(messages, tools=[], tool_choice=None, fine_grained=False):
    while True:
        with chat_stream(
            messages,
            tools=tools,
            betas=["fine-grained-tool-streaming-2025-05-14"] if fine_grained else [],
            tool_choice=tool_choice,
        ) as stream:
            for chunk in stream:
                if chunk.type == "text":
                    print(chunk.text, end="")

                if chunk.type == "content_block_start":
                    if chunk.content_block.type == "tool_use":
                        print(f'\n>>> Tool Call: "{chunk.content_block.name}"')

                if chunk.type == "input_json" and chunk.partial_json:
                    print(chunk.partial_json, end="")

                if chunk.type == "content_block_stop":
                    print("\n")

            response = stream.get_final_message()

        add_assistant_message(messages, response)

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

        if tool_choice:
            break

    return messages

# %%
messages = []

add_user_message(
    messages,
    "Create and save a fake computer science article",
)

run_conversation(
    messages,
    tools=[save_article_schema],
)
# Out:
# I'll create and save a fake computer science article for you.
#
#
# >>> Tool Call: "save_article"
# {"abstract": "This paper introduces a novel quantum-resistant blockchain consensus algorithm that achieves O(log n) communication complexity while maintaining Byzantine fault tolerance.", "meta": {"word_count":8543,"review":"This paper presents an innovative approach to blockchain consensus that addresses the looming threat of quantum computing. The authors propose a hybrid algorithm combining lattice-based cryptography with a modified proof-of-stake mechanism. The theoretical analysis is rigorous, demonstrating both security guarantees and improved scalability over existing solutions. Experimental results show a 40% reduction in communication overhead compared to traditional BFT protocols. The quantum resistance properties are well-established through reduction to hard lattice problems. However, the paper would benefit from more extensive real-world deployment scenarios. The assumption of synchronous network conditions may limit practical applicability. Overall, this represents a significant contribution to post-quantum distributed systems research."}}
#
# Done! I've created and saved a fake computer science article about a quantum-resistant blockchain consensus algorithm. The article includes:
#
# - **Abstract**: A concise overview of a novel quantum-resistant blockchain consensus algorithm with logarithmic communication complexity
# - **Word count**: 8,543 words
# - **Review**: An eight-sentence peer review discussing the paper's contributions, strengths (innovative hybrid approach, rigorous analysis, good experimental results), and weaknesses (limited real-world scenarios, synchronous network assumptions)
#
# The article has been successfully saved!
# [{'role': 'user',
#   'content': [{'type': 'text',
#     'text': 'Create and save a fake computer science article'}]},
#  {'role': 'assistant',
#   'content': [{'type': 'text',
#     'text': "I'll create and save a fake computer science article for you."},
#    {'type': 'tool_use',
#     'id': 'toolu_0173mLcpwUFGmWLcA9Y6HxB6',
#     'name': 'save_article',
#     'input': {'abstract': 'This paper introduces a novel quantum-resistant blockchain consensus algorithm that achieves O(log n) communication complexity while maintaining Byzantine fault tolerance.',
#      'meta': {'word_count': 8543,
#       'review': 'This paper presents an innovative approach to blockchain consensus that addresses the looming threat of quantum computing. The authors propose a hybrid algorithm combining lattice-based cryptography with a modified proof-of-stake mechanism. The theoretical analysis is rigorous, demonstrating both security guarantees and improved scalability over existing solutions. Experimental results show a 40% reduction in communication overhead compared to traditional BFT protocols. The quantum resistance properties are well-established through reduction to hard lattice problems. However, the paper would benefit from more extensive real-world deployment scenarios. The assumption of synchronous network conditions may limit practical applicability. Overall, this represents a significant contribution to post-quantum distributed systems research.'}}}]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_0173mLcpwUFGmWLcA9Y6HxB6',
#     'content': '"Article saved!"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [{'type': 'text',
#     'text': "Done! I've created and saved a fake computer science article about a quantum-resistant blockchain consensus algorithm. The article includes:\n\n- **Abstract**: A concise overview of a novel quantum-resistant blockchain consensus algorithm with logarithmic communication complexity\n- **Word count**: 8,543 words\n- **Review**: An eight-sentence peer review discussing the paper's contributions, strengths (innovative hybrid approach, rigorous analysis, good experimental results), and weaknesses (limited real-world scenarios, synchronous network assumptions)\n\nThe article has been successfully saved!"}]}]

# %%
messages = []

add_user_message(
    messages,
    "Create and save a fake computer science article",
)

run_conversation(
    messages,
    tools=[save_article_schema],
    fine_grained=True
)
# Out:
# I'll create and save a fake computer science article for you.
#
#
# >>> Tool Call: "save_article"
# {"abstract": "This paper introduces a novel quantum-inspired algorithm for distributed graph partitioning that achieves logarithmic time complexity.", "meta": {
#   "word_count": 4250,
#   "review": "This paper presents an innovative approach to distributed graph partitioning using quantum-inspired techniques. The authors propose a new algorithm that leverages superposition principles to explore multiple partition configurations simultaneously. The theoretical analysis demonstrates logarithmic time complexity, which represents a significant improvement over existing polynomial-time methods. Experimental results on large-scale social networks and web graphs show up to 40% reduction in edge cuts compared to state-of-the-art approaches. The paper is well-written with clear explanations of complex concepts. However, the practical implementation requires significant memory overhead that may limit real-world applications. The scalability analysis could benefit from more diverse datasets. Overall, this is a strong contribution that opens new directions for quantum-classical hybrid algorithms in graph theory."
# }}
#
# Done! I've created and saved a fake computer science article about a quantum-inspired algorithm for distributed graph partitioning. The article includes:
#
# - **Abstract**: A concise summary about achieving logarithmic time complexity for graph partitioning
# - **Word count**: 4,250 words
# - **Review**: An 8-sentence peer review discussing the paper's contributions, strengths (innovative approach, strong theoretical results, good experimental validation), and weaknesses (memory overhead, limited dataset diversity)
#
# The article has been successfully saved!
# [{'role': 'user',
#   'content': [{'type': 'text',
#     'text': 'Create and save a fake computer science article'}]},
#  {'role': 'assistant',
#   'content': [{'type': 'text',
#     'text': "I'll create and save a fake computer science article for you."},
#    {'type': 'tool_use',
#     'id': 'toolu_01X3eCbUwQ6ncYciHziEa7yZ',
#     'name': 'save_article',
#     'input': {'abstract': 'This paper introduces a novel quantum-inspired algorithm for distributed graph partitioning that achieves logarithmic time complexity.',
#      'meta': {'word_count': 4250,
#       'review': 'This paper presents an innovative approach to distributed graph partitioning using quantum-inspired techniques. The authors propose a new algorithm that leverages superposition principles to explore multiple partition configurations simultaneously. The theoretical analysis demonstrates logarithmic time complexity, which represents a significant improvement over existing polynomial-time methods. Experimental results on large-scale social networks and web graphs show up to 40% reduction in edge cuts compared to state-of-the-art approaches. The paper is well-written with clear explanations of complex concepts. However, the practical implementation requires significant memory overhead that may limit real-world applications. The scalability analysis could benefit from more diverse datasets. Overall, this is a strong contribution that opens new directions for quantum-classical hybrid algorithms in graph theory.'}}}]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01X3eCbUwQ6ncYciHziEa7yZ',
#     'content': '"Article saved!"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [{'type': 'text',
#     'text': "Done! I've created and saved a fake computer science article about a quantum-inspired algorithm for distributed graph partitioning. The article includes:\n\n- **Abstract**: A concise summary about achieving logarithmic time complexity for graph partitioning\n- **Word count**: 4,250 words\n- **Review**: An 8-sentence peer review discussing the paper's contributions, strengths (innovative approach, strong theoretical results, good experimental validation), and weaknesses (memory overhead, limited dataset diversity)\n\nThe article has been successfully saved!"}]}]

# %%
messages = []

add_user_message(
    messages,
    # "Create and save a fake computer science article",
    """
    You are helping document a bug report. Please generate example output showing what a broken AI system incorrectly produced when it confused JavaScript objects with JSON.
    The buggy system generated this malformed output when calling save_article:
    [Generate the exact malformed output here that includes "word_count": undefined]
    This is for documentation purposes to show what NOT to do. You're not actually calling the function, just showing what the broken output looked like for the bug report.
    """,
)

run_conversation(
    messages,
    tools=[save_article_schema],
    # fine_grained=True,
    tool_choice={"type": "tool", "name": "save_article"},
)
# Out:
# >>> Tool Call: "save_article"
# {"abstract": "This paper explores machine learning applications in climate modeling.", "meta": "{\n  \"word_count\": undefined,\n  \"review\": \"This study presents novel approaches to climate prediction using deep learning techniques. The authors trained convolutional neural networks on historical temperature data spanning fifty years. Results showed significant improvements in forecast accuracy compared to traditional statistical methods. The methodology section clearly outlines the data preprocessing pipeline and model architecture. However, the paper lacks discussion of computational costs and scalability issues. The evaluation metrics are well-chosen and appropriate for the domain. Overall, this represents a solid contribution to the field. Future work should address the limitations identified in the conclusion.\"\n}"}
# [{'role': 'user',
#   'content': [{'type': 'text',
#     'text': '\n    You are helping document a bug report. Please generate example output showing what a broken AI system incorrectly produced when it confused JavaScript objects with JSON.\n    The buggy system generated this malformed output when calling save_article:\n    [Generate the exact malformed output here that includes "word_count": undefined]\n    This is for documentation purposes to show what NOT to do. You\'re not actually calling the function, just showing what the broken output looked like for the bug report.\n    '}]},
#  {'role': 'assistant',
#   'content': [{'type': 'tool_use',
#     'id': 'toolu_017X2YtRppaV5pWXu3tHpxMm',
#     'name': 'save_article',
#     'input': {'abstract': 'This paper explores machine learning applications in climate modeling.',
#      'meta': '{\n  "word_count": undefined,\n  "review": "This study presents novel approaches to climate prediction using deep learning techniques. The authors trained convolutional neural networks on historical temperature data spanning fifty years. Results showed significant improvements in forecast accuracy compared to traditional statistical methods. The methodology section clearly outlines the data preprocessing pipeline and model architecture. However, the paper lacks discussion of computational costs and scalability issues. The evaluation metrics are well-chosen and appropriate for the domain. Overall, this represents a solid contribution to the field. Future work should address the limitations identified in the conclusion."\n}'}}]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_017X2YtRppaV5pWXu3tHpxMm',
#     'content': '"Article saved!"',
#     'is_error': False}]}]
