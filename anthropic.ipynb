# %%
import os

# %%
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in ./.venv/lib/python3.10/site-packages (0.97.0)
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: docstring-parser<1,>=0.15 in ./.venv/lib/python3.10/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.10/site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: typing-extensions<5,>=4.14 in ./.venv/lib/python3.10/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./.venv/lib/python3.10/site-packages (from anthropic) (2.13.3)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.10/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in ./.venv/lib/python3.10/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.10/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./.venv/lib/python3.10/site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->anthropic) (3.13)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->anthropic) (1.3.1)
# Requirement already satisfied: certifi in ./.venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Requirement already satisfied: pydantic-core==2.46.3 in ./.venv/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.3)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.2.2
#
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"

# %%
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "What is quantum computing? Answer in one sentence."
        }
    ]
)

# %%
message
# Out:
# Message(id='msg_01GPj4E1zSPSoS1f7Q82nCvj', container=None, content=[TextBlock(citations=None, text='Quantum computing uses quantum bits (qubits) that exploit superposition and entanglement to process information in fundamentally different ways than classical computers, enabling faster solutions to certain complex problems.', type='text')], model='claude-haiku-4-5-20251001', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=17, output_tokens=42, server_tool_use=None, service_tier='standard'))

# %%
message.content[0].text
# Out:
# 'Quantum computing uses quantum bits (qubits) that exploit superposition and entanglement to process information in fundamentally different ways than classical computers, enabling faster solutions to certain complex problems.'

# %%
def add_user_messages(messages, text):
    user_message  = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_messages(messages, text):
    assistant_message  = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text
